# %% [markdown]
# # Data Description

# %% [markdown]
# List of postal codes for South Korea: https://en.wikipedia.org/wiki/List_of_postal_codes_in_South_Korea
# List of postal codes for Toronto: https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M

# %% [markdown]
# # Other Information

# %% [markdown]
# Will use:
#
# Neighborhood latitude and longitude
# Zip codes, and
# Get nearby venues,
# Venue categories, and
# Latitude and longitude of the Venues
#
# It will also be noted how many Korean restaurants are nearby and fast food places there are, as fast food places are in both Korea and Canada. Additionally we will see how common those venues are in both neighborhoods. This will all be done through Foursquare API, also using FourSquare features.
